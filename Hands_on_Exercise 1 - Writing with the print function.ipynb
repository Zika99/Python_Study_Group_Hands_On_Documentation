# %% [markdown]
# # Exercise 1 – Printing Text (Beginner)

# %%
print("Hello, World!")
print("My name is Ngozi Bridget")
print("I am learning Python.")
print("Programming is exciting!")
# Out:
# Hello, World!
# My name is Ngozi Bridget
# I am learning Python.
# Programming is exciting!

# %% [markdown]
# # Exercise 2 – Multiple Print Statements (Beginner)

# %%
print("My favorite food is Plantain with egg sauce.")
print("My favorite movie is Avatar.")
print("My favorite sport is track races.")
print("My favorite color is Pink.")
# Out:
# My favorite food is Plantain with egg sauce.
# My favorite movie is Avatar.
# My favorite sport is track races.
# My favorite color is Pink.

# %% [markdown]
# # Exercise 3 – Python Calculator

# %%
print(15 + 5)
print(30 - 12)
print(9 * 8)
print(72 / 9)
print(18 % 5)
print(10 // 3)
print(5**2)
# Out:
# 20
# 18
# 72
# 8.0
# 3
# 3
# 25

# %% [markdown]
# # Exercise 4 – Understanding Comments

# %% [markdown]
# # Display programming language
# print("Python")
#
# # Display the subject
# print("Programming")
#
# # Display the lesson title
# print("Lesson One")

# %% [markdown]
# # Exercise 5 – Mini Challenge

# %% [markdown]
# ## Write a program that:
# - Prints your name
# - Prints your dream career
# - Prints your country
# - Calculates 25 + 75
# - Calculates 40 // 6
# - Calculates 8²
# -Includes at least three comments

# %%
print("Ngozi Bridget")
print("Data Engineering")
print("Nigeria")
print(25 + 75)
print(40 // 6)
print(8**2)
# Out:
# Ngozi Bridget
# Data Engineering
# Nigeria
# 100
# 6
# 64

# %% [markdown]
# - My name is Ngozi Bridget, an aspiring data engineer.
# - The // operator is called a floor division and it returns only the whole number after dividing.
# - The ** operator is called the exponent operator and it used to raise a number to power of another number. In our own case, 8 was raised to the power of 2 to give us 64.
